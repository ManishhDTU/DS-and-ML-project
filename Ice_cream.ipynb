# %% [markdown]
# <a href="https://colab.research.google.com/github/ManishhDTU/DS-and-ML-project/blob/main/Ice_cream.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ice Cream Sales Revenue Prediction

# %%
import pandas as pd

# %%
ice_cream = pd.read_csv("https://github.com/YBI-Foundation/Dataset/raw/main/Ice%20Cream.csv")

# %%
ice_cream
# Out:
#      Temperature  Revenue
# 0           24.6      535
# 1           26.1      626
# 2           27.8      661
# 3           20.6      488
# 4           11.6      317
# ..           ...      ...
# 495         22.3      525
# 496         32.9      756
# 497         12.6      307
# 498         22.4      567
# 499         29.0      656
#
# [500 rows x 2 columns]

# %%
ice_cream.head()
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626
# 2         27.8      661
# 3         20.6      488
# 4         11.6      317

# %%
ice_cream.tail()
# Out:
#      Temperature  Revenue
# 495         22.3      525
# 496         32.9      756
# 497         12.6      307
# 498         22.4      567
# 499         29.0      656

# %%
ice_cream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 7.9 KB

# %%
ice_cream.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.281600   522.058000
# std       8.097597   175.410399
# min       0.000000    10.000000
# 25%      17.175000   406.000000
# 50%      22.400000   530.000000
# 75%      27.800000   643.000000
# max      45.000000  1000.000000

# %%
ice_cream.columns
# Out:
# Index(['Temperature', 'Revenue'], dtype='object')

# %%
y = ice_cream["Revenue"]
y.shape
# Out:
# (500,)

# %%
# x = ice_cream[["Temperature"]]
# x.shape

# %%
x = ice_cream.drop(["Revenue"], axis=1)
x.shape
# Out:
# (500, 1)

# %%
y, x
# Out:
# (0      535
#  1      626
#  2      661
#  3      488
#  4      317
#        ...
#  495    525
#  496    756
#  497    307
#  498    567
#  499    656
#  Name: Revenue, Length: 500, dtype: int64,
#       Temperature
#  0           24.6
#  1           26.1
#  2           27.8
#  3           20.6
#  4           11.6
#  ..           ...
#  495         22.3
#  496         32.9
#  497         12.6
#  498         22.4
#  499         29.0
#
#  [500 rows x 1 columns])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size= 0.75 ,random_state=2529)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((375, 1), (125, 1), (375,), (125,))

# %%
x_train, y_train
# Out:
# (     Temperature
#  443         30.1
#  440         31.1
#  82          22.2
#  94          12.4
#  313         27.1
#  ..           ...
#  228         38.2
#  399         33.6
#  316         25.2
#  50           6.4
#  352         12.8
#
#  [375 rows x 1 columns],
#  443    699
#  440    685
#  82     516
#  94     338
#  313    595
#        ...
#  228    851
#  399    751
#  316    588
#  50     191
#  352    296
#  Name: Revenue, Length: 375, dtype: int64)

# %%
x_test, y_test
# Out:
# (     Temperature
#  163         28.0
#  45          15.7
#  244          6.4
#  230          9.5
#  421         17.3
#  ..           ...
#  274         22.3
#  252          7.6
#  306         32.5
#  84          29.3
#  243         15.1
#
#  [125 rows x 1 columns],
#  163    649
#  45     397
#  244    192
#  230    279
#  421    406
#        ...
#  274    536
#  252    213
#  306    760
#  84     655
#  243    368
#  Name: Revenue, Length: 125, dtype: int64)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 44.018097590245816

# %%
model.coef_
# Out:
# array([21.4695184])

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([645.16461281, 381.08953648, 181.42301535, 247.9785224 ,
#        415.44076592, 284.47670368, 372.50172912, 670.92803489,
#        675.22193857, 683.80974593, 531.37616528, 612.9603352 ,
#        361.76696992, 303.79927024, 159.95349695, 473.4084656 ,
#        610.81338336, 615.10728704, 512.05359872, 804.03904897,
#        269.4480408 , 441.204188  , 436.91028432, 859.85979681,
#        531.37616528, 217.92119663, 724.60183089, 312.3870776 ,
#        505.6127432 , 466.96761008, 683.80974593, 958.61958145,
#        550.69873184, 615.10728704, 368.20782544, 404.70600672,
#        413.29381408, 662.34022753, 874.88845969, 544.25787632,
#        810.47990449, 685.95669777, 486.29017664, 323.1218368 ,
#        636.57680544, 797.59819345, 439.05723616, 789.01038609,
#        683.80974593, 497.02493584, 381.08953648, 479.84932112,
#        479.84932112, 563.58044288, 664.48717937, 454.08589904,
#        688.10364961, 647.31156465, 391.82429568, 662.34022753,
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 517.4978493670571

# %%
mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.04155209268159155

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 18.369558283712276

# %% [markdown]
# # Second Method for the analysis of Ice cream data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("https://github.com/YBI-Foundation/Dataset/raw/main/Ice%20Cream.csv")

# %%
data
# Out:
#      Temperature  Revenue
# 0           24.6      535
# 1           26.1      626
# 2           27.8      661
# 3           20.6      488
# 4           11.6      317
# ..           ...      ...
# 495         22.3      525
# 496         32.9      756
# 497         12.6      307
# 498         22.4      567
# 499         29.0      656
#
# [500 rows x 2 columns]

# %%
data.head()
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626
# 2         27.8      661
# 3         20.6      488
# 4         11.6      317

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 7.9 KB

# %%
data.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.281600   522.058000
# std       8.097597   175.410399
# min       0.000000    10.000000
# 25%      17.175000   406.000000
# 50%      22.400000   530.000000
# 75%      27.800000   643.000000
# max      45.000000  1000.000000

# %%
data.columns
# Out:
# Index(['Temperature', 'Revenue'], dtype='object')

# %%
data.dtypes
# Out:
# Temperature    float64
# Revenue          int64
# dtype: object

# %%
data.isnull()
# Out:
#      Temperature  Revenue
# 0          False    False
# 1          False    False
# 2          False    False
# 3          False    False
# 4          False    False
# ..           ...      ...
# 495        False    False
# 496        False    False
# 497        False    False
# 498        False    False
# 499        False    False
#
# [500 rows x 2 columns]

# %%
data.isnull().sum()
# Out:
# Temperature    0
# Revenue        0
# dtype: int64

# %%
data.boxplot(column =["Temperature"])
# Out:
# <Axes: >

# %%
data.boxplot(["Revenue"])
# Out:
# <Axes: >

# %%
data.boxplot(column=["Temperature", "Revenue"])
# Out:
# <Axes: >

# %%
# Dropping Serial No columnsas it is not required for prediction
data1 = data.copy()
data1
# Out:
#      Temperature  Revenue
# 0           24.6      535
# 1           26.1      626
# 2           27.8      661
# 3           20.6      488
# 4           11.6      317
# ..           ...      ...
# 495         22.3      525
# 496         32.9      756
# 497         12.6      307
# 498         22.4      567
# 499         29.0      656
#
# [500 rows x 2 columns]

# %%
# Calculating Quartiles of each feature
Q1 = data1.quantile(0.25)
Q3 = data1.quantile(0.75)
IQR = Q3 -Q1
print(IQR)
# Out:
# Temperature     10.625
# Revenue        237.000
# dtype: float64

# %%
# Identifying Outliers
df_out1 = data1[((data1 < (Q1 - 1.5 * IQR)) | (data1 > (Q3 + 1.5 * IQR))).any(axis=1)]
df_out1
# Out:
#      Temperature  Revenue
# 8            1.0       56
# 371          0.3       33
# 402          0.0       10
# 444         45.0     1000

# %%
# removing outliers
df_out = data1.loc[~((data1 < (Q1 - 1.5 * IQR)) | (data1 > (Q3 + 1.5 * IQR))).any(axis=1)]
data = df_out.copy()
print(data.shape)
# Out:
# (496, 2)

# %%
data["Temperature"].plot.hist()
plt.xlabel("Temp.", fontsize = 14)
# Out:
# Text(0.5, 0, 'Temp.')

# %%
data["Revenue"].plot.hist()
plt.xlabel("Revenue", fontsize = 14)
# Out:
# Text(0.5, 0, 'Revenue')

# %%
data.plot.scatter("Temperature", "Revenue")
# Out:
# <Axes: xlabel='Temperature', ylabel='Revenue'>

# %%
data["Temperature"].corr(data["Revenue"])
# Out:
# 0.9892282994493732

# %%
# separting independent and dependent variable
x = data[["Revenue"]]
y = data["Temperature"]
x.shape, y.shape
# Out:
# ((496, 1), (496,))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=2529)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((347, 1), (149, 1), (347,), (149,))

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# -1.4342893912531238

# %%
model.coef_
# Out:
# array([0.04545444])

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([ 9.38386633, 15.24748854, 24.70201119, 19.15657002, 28.52018379,
#        35.3838036 , 20.06565874, 27.65654951, 26.65655193, 34.15653383,
#        21.33838294, 30.02018017, 29.70199912, 20.11111317, 17.06566597,
#        22.11110835, 25.02019224, 32.56562858,  9.79295625, 26.42927975,
#        24.20201239, 28.11109387, 37.56561651, 23.15656037, 28.20200274,
#        29.65654469,  9.56568407, 27.11109628, 26.70200636, 34.97471367,
#        27.97473056, 25.11110111, 29.61109025,  9.29295745, 31.61108543,
#        38.15652418, 19.52020551, 15.83839621, 21.47474625, 21.15656519,
#        11.06568045, 25.79291765, 32.9747185 , 22.97474263, 30.70199671,
#        29.47472694, 23.0656515 ,  5.20205823, 30.52017897, 11.24749819,
#        35.3838036 , 25.83837208, 23.79292247, 26.02018982, 25.33837329,
#        28.29291161, 35.3838036 , 24.70201119, 19.02020671, 24.29292126,
#        35.83834795, 15.61112403, 24.88382893, 13.74749216, 28.06563943,
# ...

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 1.1869938125999975

# %%
mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.04523058330902099

# %%
# Model Evaluation  ---- I don't have Idea of that

# %%
# train_performance = np.sqrt(mean_squared_error(y_test, y_pred))
# print(train_performance)

# %%
# test_performance = np.sqrt(mean_squared_error(y_test, y_pred))
# print(test_performance)
